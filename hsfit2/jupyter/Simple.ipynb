// %%
gROOT->ProcessLine(".x $HSCODE/hsfit2/LoadFit.C+")
// Out:
// Info in <TUnixSystem::ACLiC>: creating shared library /work/Dropbox/HaSpect/dev/HASPECT6/hsfit2/LoadFit_C.so
// Warning in cling::IncrementalParser::CheckABICompatibility():
//   Possible C++ standard library mismatch, compiled with __GLIBCXX__ '20180415'
//   Extraction of runtime standard library version was: '20180720'
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ FiledTree
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ Bins
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ Weights
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ RooHSEventsPDF
//
// RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
//                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
//                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
//
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ RooHSEventsHistPDF
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ Setup
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ Data
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ Binner
// ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ PlotResults
// ...

// %%
  sPlot RF;
  RF.SetUp().SetOutDir("out/");
  ///////////////////////////////Load Variables
  RF.SetUp().LoadVariable("Mmiss[0,10]");//should be same name as variable in tree  
  RF.SetUp().SetIDBranchName("fgID");

// %%
  /////////////////////////////Make Model Signal
  RF.SetUp().FactoryPDF("Gaussian::Signal( Mmiss, SIMm[6,4,7], SIMw[0.2,0.0001,3] )");
  RF.SetUp().LoadSpeciesPDF("Signal",1);

// %%
  ////////////////////////////////Additional background
  RF.SetUp().FactoryPDF("Chebychev::BG(Mmiss,{a0[-0.1,-1,1],a1[0.1,-1,1]})");
  RF.SetUp().LoadSpeciesPDF("BG",1);

// %%
  ////////////////////////////Make Bins
  RF.Bins().LoadBinVar("Eg",4,3,4);

// %%
  ///////////////////////////Load Data
  RF.LoadData("MyModel","/work/Dropbox/HaSpect/dev/HASPECT6/RooFitExamples2/sPlotSimple/Data.root");
// Out:
// Bins::RunBinTree Running bins from 0 to 4
// Constructing Bin Tree out//Eg3.12_/TreeData
// Constructing Bin Tree out//Eg3.38_/TreeData
// Constructing Bin Tree out//Eg3.62_/TreeData
// Constructing Bin Tree out//Eg3.88_/TreeData
// On event 0 = 0%
// BinTree::Save() out//Eg3.12_/TreeData
// BinTree::Save() out//Eg3.38_/TreeData
// BinTree::Save() out//Eg3.62_/TreeData
// BinTree::Save() out//Eg3.88_/TreeData
// Info in <HS::Bins:: Bins::Save()>:  Saving HSBins to out/DataBinsConfig.root
// FiledTree::~FiledTree()  tree name MyModel 100000 /work/Dropbox/HaSpect/dev/HASPECT6/RooFitExamples2/sPlotSimple/Data.root

// %%
%jsroot

// %%
 RF.RunAll();
// Out:
// HS::FIT::sPlot::Do prelimanry fits PyROOT
// %%%%%%%%%%%%%%%%%%%%%copy setup
//  DataEvents::Get 0 4
//  RooAbsData& DataEvents::Get 4 out//Eg3.12_/TreeData.root BinnedTree
// RooArgSet:: = (Mmiss)
//
//  FitManager::FillEventsPDFs 2
// 0 0
// 1 0
// RooAddPdf::Eg3.12_TotalPDF[ Yld_Signal * Signal + Yld_BG * BG ] = 0.450002
//  DataEvents::Get 0 4
// FitManager::Run start fit
// 0x7f53837b0220 : OBJ: RooCmdArg	NumCPU	NumCPU
// 0x7f5383e1d590 : OBJ: RooCmdArg	Save	Save
// 0x7f5383bfb460 : OBJ: RooCmdArg	Warnings	Warnings
// 0x7f5383806fc0 : OBJ: RooCmdArg	Minos	Minos
// 0x7f537466cc10 : OBJ: RooCmdArg	Extended	Extended
// 0x7f537471cda0 : OBJ: RooCmdArg	ExternalConstraints	ExternalConstraints
// [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
// [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (Signal,BG)
//  **********
//  **    1 **SET PRINT           1
//  **********
//  **********
// ...
